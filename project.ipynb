# %%
import pandas as pd

df = pd.read_csv("ufo_data.csv", encoding = "utf-8", on_bad_lines = 'skip', low_memory = False)
df
# Out:
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 88674    9/9/2013 22:00                  napa    ca      us     other
# 88675    9/9/2013 22:20                vienna    va      us    circle
# 88676    9/9/2013 23:00                edmond    ok      us     cigar
# 88677    9/9/2013 23:00                 starr    sc      us   diamond
# 88678    9/9/2013 23:30        ft. lauderdale    fl      us      oval
#
#       duration (seconds) duration (hours/min)  \
# 0                   2700           45 minutes
# ...

# %%
df.describe()
# Out:
#           longitude
# count  88679.000000
# mean     -85.021836
# std       41.421744
# min     -176.658056
# 25%     -112.073333
# 50%      -87.650000
# 75%      -77.769738
# max      178.441900

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88679 entries, 0 to 88678
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              88679 non-null  object
#  1   city                  88679 non-null  object
#  2   state                 81270 non-null  object
#  3   country               76314 non-null  object
#  4   shape                 85757 non-null  object
#  5   duration (seconds)    88677 non-null  object
#  6   duration (hours/min)  85660 non-null  object
#  7   comments              88644 non-null  object
#  8   date posted           88679 non-null  object
#  9   latitude              88679 non-null  object
#  10  longitude             88679 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 7.4+ MB

# %%
# Now as you can see some features are of object type . we need to convret them into
# their correct data type

# %%
df
# Out:
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 88674    9/9/2013 22:00                  napa    ca      us     other
# 88675    9/9/2013 22:20                vienna    va      us    circle
# 88676    9/9/2013 23:00                edmond    ok      us     cigar
# 88677    9/9/2013 23:00                 starr    sc      us   diamond
# 88678    9/9/2013 23:30        ft. lauderdale    fl      us      oval
#
#       duration (seconds) duration (hours/min)  \
# 0                   2700           45 minutes
# ...

# %%
import pandas as pd

df["datetime"] = pd.to_datetime(df["datetime"],errors = "coerce")
df["date posted"] = pd.to_datetime(df["date posted"], errors = "coerce")

df["latitude"] = pd.to_numeric(df["latitude"] , errors = 'coerce')

df["longitude"] = pd.to_numeric(df["longitude"], errors = 'coerce')

df["duration (seconds)"] = pd.to_numeric(df["duration (seconds)"], errors = 'coerce')

# Convert the 'duration (hours/min)' column to string before using .str accessor
df['duration (hours/min)'] = df['duration (hours/min)'].astype(str)

# Now extract the number from the 'duration (hours/min)' column
df['duration (hours/min)'] = df['duration (hours/min)'].str.extract('(\\d+)', expand=False)

# Convert the extracted values to numeric
df["duration (hours/min)"] = pd.to_numeric(df["duration (hours/min)"], errors='coerce')


df["city"] = df["city"].astype("category")
df["state"] = df["state"].astype("category")
df["shape"] = df["shape"].astype("category")
df["country"] = df["country"].astype("category")
df["comments"] = df["comments"].astype("category")

# %%
df.shape[1]# 0 for rows and 1 for columns
# Out:
# 11

# %%
df.shape[0]
# Out:
# 88679

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88679 entries, 0 to 88678
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              87459 non-null  datetime64[ns]
#  1   city                  88679 non-null  category
#  2   state                 81270 non-null  category
#  3   country               76314 non-null  category
#  4   shape                 85757 non-null  category
#  5   duration (seconds)    88674 non-null  float64
#  6   duration (hours/min)  79161 non-null  float64
#  7   comments              88644 non-null  category
#  8   date posted           88679 non-null  datetime64[ns]
#  9   latitude              88678 non-null  float64
#  10  longitude             88679 non-null  float64
# dtypes: category(5), datetime64[ns](2), float64(4)
# memory usage: 8.2 MB

# %%
# Okay now we have put this dataset into correct format.

# %%
df.isna()
# Out:
#        datetime   city  state  country  shape  duration (seconds)  \
# 0         False  False  False    False  False               False
# 1         False  False  False     True  False               False
# 2         False  False   True    False  False               False
# 3         False  False  False    False  False               False
# 4         False  False  False    False  False               False
# ...         ...    ...    ...      ...    ...                 ...
# 88674     False  False  False    False  False               False
# 88675     False  False  False    False  False               False
# 88676     False  False  False    False  False               False
# 88677     False  False  False    False  False               False
# 88678     False  False  False    False  False               False
#
#        duration (hours/min)  comments  date posted  latitude  longitude
# 0                     False     False        False     False      False
# ...

# %%
df.isna().sum()
# Out:
# datetime                 1220
# city                        0
# state                    7409
# country                 12365
# shape                    2922
# duration (seconds)          5
# duration (hours/min)     9518
# comments                   35
# date posted                 0
# latitude                    1
# longitude                   0
# dtype: int64

# %%
# now as u can see there are number of NAN values thus we first need to fill it or either 
# drop it

# %%
# we see that datetime has high number of NaN values so we need to drop it
# state, country,shape comments are categorical so we will use fillna
# numerical datas with NaN will get replaced with the mean or median values

# %%
# This is Data Cleaning

df.dropna(subset=["datetime"], inplace=True)  

for col in ["state", "country", "shape", "comments"]:
    if "Unknown" not in df[col].cat.categories:  # Only add if not already present
        df[col] = df[col].cat.add_categories("Unknown")
    df[col] = df[col].fillna("Unknown")  # Assign back instead of inplace=True

df["duration (seconds)"] = df["duration (seconds)"].fillna(df["duration (seconds)"].median())
df["duration (hours/min)"] = df["duration (hours/min)"].fillna(df["duration (hours/min)"].median())
df["latitude"] = df["latitude"].fillna(df["latitude"].median())

# %%
df.isna().sum()  # We filled the data
# Out:
# datetime                0
# city                    0
# state                   0
# country                 0
# shape                   0
# duration (seconds)      0
# duration (hours/min)    0
# comments                0
# date posted             0
# latitude                0
# longitude               0
# dtype: int64

# %%
# Data Visualizations

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style = "whitegrid")

# Top 10 most common UFO shapes

shapes = df["shape"].value_counts().head(10)
plt.figure(figsize = (10,6))
sns.barplot(x = shapes.index, y = shapes.values)
plt.title('Top 10 Most Common UFO Shapes')
plt.xlabel('Shape')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# Ufo sightings by year top 10
df['year'] = df['datetime'].dt.year
top_10_years = df['year'].value_counts().nlargest(10)
plt.figure(figsize=(10, 6))
sns.countplot(data=df[df['year'].isin(top_10_years.index)], x='year', order=top_10_years.index)
plt.title('Top 10 UFO Sightings by Year')
plt.xlabel('Year')
plt.ylabel('Number of Sightings')
plt.xticks(rotation=45)
plt.show()

# UFO sightings by country

top_countries = df['country'].value_counts().head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_countries.index, y=top_countries.values)
plt.title('Top 10 Countries with Most UFO Sightings')
plt.xlabel('Country')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# Pie chart for the top 10 UFO sightings by year
df['year'] = df['datetime'].dt.year
top_10_years = df['year'].value_counts().nlargest(10)
plt.figure(figsize=(8, 8))
plt.pie(top_10_years.values, labels=top_10_years.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("viridis", len(top_10_years)))
plt.title('Top 10 UFO Sightings by Year')
plt.axis('equal')  
plt.show()

# %%
# Lets start with feature Engineering

# %%
import pandas as pd
import numpy as np
from geopy.distance import geodesic
from sklearn.preprocessing import StandardScaler

# Ensure datetime column exists and is converted to datetime if necessary
if 'datetime' in df.columns:
    df['datetime'] = pd.to_datetime(df['datetime'], errors='coerce')
else:
    raise ValueError("The 'datetime' column is missing.")

# 1. Extracting date-time components (if not already done)
df['year'] = df['datetime'].dt.year
df['month'] = df['datetime'].dt.month
df['day'] = df['datetime'].dt.day
df['hour'] = df['datetime'].dt.hour
df['day_of_week'] = df['datetime'].dt.dayofweek  # 0=Monday, 6=Sunday
df['week_of_year'] = df['datetime'].dt.isocalendar().week

# 2. Create temporal features like weekend check based on day_of_week
df['is_weekend'] = df['day_of_week'].apply(lambda x: 1 if x >= 5 else 0)  # 1 if weekend, else 0

# 3. Creating interaction features (example)
df['duration_per_hour'] = df['duration (seconds)'] / 3600  # Convert duration from seconds to hours

# 4. Geospatial features: Calculating distance from a central point (for example, from (0,0))
central_point = (0, 0)  # Example, you can choose any location like (40.7128, -74.0060) for NYC

# Calculate distance for each observation
df['distance_from_origin'] = df.apply(lambda row: geodesic(central_point, (row['latitude'], row['longitude'])).km, axis=1)

# 5. Encoding categorical features using Label Encoding
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# Apply label encoding to each categorical column
categorical_columns = ['state', 'country', 'shape', 'comments']
for col in categorical_columns:
    df[col] = label_encoder.fit_transform(df[col])

# 6. Feature scaling (for numerical columns)
numerical_columns = ['duration (seconds)', 'duration (hours/min)', 'latitude', 'longitude', 'distance_from_origin', 'duration_per_hour']
scaler = StandardScaler()
df[numerical_columns] = scaler.fit_transform(df[numerical_columns])

# 7. Dropping unnecessary columns (if any)
df.drop(columns=["date posted"], inplace=True)  # Dropping date posted for simplicity

# 8. Checking the final feature set
print(df.head())
# Out:
#              datetime                  city  state  country  shape  \
# 0 1949-10-10 20:30:00            san marcos     58        5      9
# 1 1949-10-10 21:00:00          lackland afb     58        0     19
# 2 1955-10-10 17:00:00  chester (uk/england)      0        4      5
# 3 1956-10-10 21:00:00                  edna     58        5      5
# 4 1960-10-10 20:00:00               kaneohe     14        5     19
#
#    duration (seconds)  duration (hours/min)  comments  latitude  longitude  \
# 0           -0.008591              0.324106     61716 -0.658694  -0.309934
# 1           -0.000652             -0.107393      1941 -0.701994  -0.325472
# 2           -0.013319              0.078936     28049  1.365238   1.997211
# 3           -0.013319             -0.107393     43449 -0.737224  -0.278485
# 4           -0.011766              0.029902     10762 -1.393463  -1.763364
#
#    year  month  day  hour  day_of_week  week_of_year  is_weekend  \
# ...

# %%
# Impelmenting PCA

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder

# %%
cat_cols = ["city", "state", "country", "shape"]
encoder  = LabelEncoder()

for i in cat_cols:
    df[i] = encoder.fit_transform(df[i])

num_cols = ["latitude", "longitude", "duration (seconds)"]    

X = df[num_cols]


scaler = StandardScaler()

scaled_data = scaler.fit_transform(X)

pca = PCA(n_components = 2)
df_pca  = pca.fit_transform(scaled_data)

df_pca = pd.DataFrame(df_pca, columns = ["PCA1", "PCA2"])
df_pca
# Out:
#            PCA1      PCA2
# 0      0.246524 -0.018765
# 1      0.266203 -0.011474
# 2      0.446874  0.013814
# 3      0.324259 -0.024401
# 4     -0.261717 -0.038231
# ...         ...       ...
# 87454 -0.687841 -0.014297
# 87455  0.047991 -0.010831
# 87456 -0.099650 -0.014993
# 87457  0.232426 -0.016670
# 87458  0.782885 -0.025959
#
# [87459 rows x 2 columns]

# %%
plt.figure(figsize = (10,6))
plt.scatter(df_pca["PCA1"].head(20), df_pca["PCA2"].head(20))
plt.title("PCA")
plt.xlabel("principal compoennt 1")
plt.ylabel("principle compoennt 2")
plt.show()
